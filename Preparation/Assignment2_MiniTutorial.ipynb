# %% [markdown]
# <h2>Suggested library: Librosa</h2>
#
# In your Jupyter Notebook environment, navigate to "new" and select "terminal"
# ![title](imgs/new_terminal.PNG)
#
# Install the Librosa library via PIP
# ![title](imgs/pip_install.PNG)

# %% [markdown]
# <h3>Or:</h3>

# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: audioread>=2.1.9 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (1.23.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (1.9.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (1.1.2)
# Requirement already satisfied: joblib>=0.14 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.0.10 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: resampy>=0.2.2 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (0.4.2)
# Requirement already satisfied: numba>=0.45.1 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (0.56.2)
# Requirement already satisfied: soundfile>=0.10.2 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: pooch>=1.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from librosa) (21.3)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.39.1)
# Requirement already satisfied: setuptools<60 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (57.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.14)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/orcun/Desktop/Media-Informatics/MRS/Assignments/Assignment2/11716448-orcun-ilker-doger/.venv/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.1)

# %% [markdown]
# <h2>Test Run</h2>

# %%
import librosa
print(librosa.__version__)
# Out:
# 0.9.2

# %%
y, sr = librosa.load(librosa.util.example("brahms"))
print("audio buffer length: ", len(y), ", sampling rate: ", sr)
# Out:
# audio buffer length:  1010880 , sampling rate:  22050

# %% [markdown]
# <h2>Resampling</h2>

# %%
new_sr = 44100
y = librosa.resample(y, orig_sr=sr, target_sr=new_sr)

# %% [markdown]
# <h2>Display interactive plots directy in Jupyter Notebook</h2>

# %%
#matplotlib as basis, used by librosa.display
import matplotlib.pyplot as plt
import librosa.display

#use styles
import matplotlib.style as ms
ms.use('seaborn-v0_8-muted')

# Render interactive figures
# %matplotlib widget

#add audio widget for playback
from IPython.display import Audio

# %%
plt.figure()
librosa.display.waveshow(y=y, sr=new_sr)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <h2>Play your Audio Files</h2>

# %%
import IPython.display as ipd
ipd.Audio(y, rate=sr) # load a NumPy array

# %% [markdown]
# Take a listen to your resampled files...

# %%
new_sr = 5512
y = librosa.resample(y, orig_sr=sr, target_sr=new_sr)

ipd.Audio(y, rate=new_sr) # load a NumPy array

# %% [markdown]
# <h2>Extracting features correctly</h2>
# Librosa offers many options to extract all kinds of features from an audio stream - but watch out for format of the data you're getting

# %% [markdown]
# Sometimes it is straight-foward:

# %%
librosa.feature.zero_crossing_rate(y)

# %% [markdown]
# Sometimes some manual steps are required:

# %%
#EXTRACT ENERGY
import numpy as np

hop_len = 256
frame_len = 512
energy = np.array([sum(abs(y[i:i + frame_len] ** 2)) for i in range(0, len(y), hop_len)])
energy

# %%
#EXTRACT TEMPO
onset_env = librosa.onset.onset_strength(y=y, sr=sr)
tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sr, aggregate=None)
tempo

# %% [markdown]
# Sometimes you Librosa gives you a multidimensional represenation of a feature which requires further processing to fit into the wanted format

# %%
hop_length = 512

mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length=hop_length, n_mfcc=13)
mfcc_averaged = mfcc.mean(axis=0)
mfcc_averaged

# %% [markdown]
# Be sure to check the documentation before extracting a feature! <p>
# http://librosa.github.io/librosa/
